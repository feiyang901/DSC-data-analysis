# %%
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
data=pd.read_excel("DSC data of TiNiNb alloy with different Nb content.xlsx")
print(data.head())
data.tail()
# Out:
#    Temperature  Heat Flow Endo Up (mW)  Temperature.1  \
# 0       122.85                 21.1994         122.82
# 1       122.85                 21.1174         122.83
# 2       122.85                 21.0261         122.83
# 3       122.84                 20.9417         122.83
# 4       122.85                 20.8605         122.83
#
#    Heat Flow Endo Up (mW).1  Temperature.2  Heat Flow Endo Up (mW).2  \
# 0                   18.4190          90.86                    0.3906
# 1                   18.4006          90.86                    0.3833
# 2                   18.3780          90.86                    0.3778
# 3                   18.3614          90.86                    0.3708
# 4                   18.3402          90.86                    0.3646
#
#    Temperature.3  Heat Flow Endo Up (mW).3  Temperature.4  \
# 0          80.59                    1.1338          85.73
# 1          80.59                    1.1193          85.73
# ...

# %%
all_data.columns
# Out:
# Index(['Temperature', 'Heat Flow Endo Up (mW)', 'Temperature.1',
#        'Heat Flow Endo Up (mW).1', 'Temperature.2', 'Heat Flow Endo Up (mW).2',
#        'Temperature.3', 'Heat Flow Endo Up (mW).3', 'Temperature.4',
#        'Heat Flow Endo Up (mW).4', 'Temperature.5', 'Heat Flow Endo Up (mW).5',
#        'Temperature.6', 'Heat Flow Endo Up (mW).6', 'Temperature.7',
#        'Heat Flow Endo Up (mW).7'],
#       dtype='object')

# %%
plt.style.use('classic')
plt.title('DSC curves', fontdict={'fontweight':'bold','fontsize':25})

plt.plot(data['Temperature'],data['Heat Flow Endo Up (mW)'],label='Nb1 base' )
plt.plot(data['Temperature.1'],data['Heat Flow Endo Up (mW).1'],label='Nb1 weld')
plt.plot(data['Temperature.2'],data['Heat Flow Endo Up (mW).2'],label='Nb3 base')
plt.plot(data['Temperature.3'],data['Heat Flow Endo Up (mW).3'],label='Nb3 weld')
plt.plot(data['Temperature.4'],data['Heat Flow Endo Up (mW).4'],label='Nb6 base')
plt.plot(data['Temperature.5'],data['Heat Flow Endo Up (mW).5'],label='Nb6 weld')
plt.plot(data['Temperature.6'],data['Heat Flow Endo Up (mW).6'],label='Nb9 base')
plt.plot(data['Temperature.7'],data['Heat Flow Endo Up (mW).7'],label='Nb9 weld')

plt.xlabel('Temperature', fontsize=20)
plt.ylabel('Heat Flow Endo Up (mW)', fontsize=20)

plt.legend(loc=2)

plt.show()
